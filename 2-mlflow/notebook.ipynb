# %% [markdown]
# # Excercises
# # 1. Tune the network
# Run the experiment below, explore the different parameters (see suggestions below) and study the result with tensorboard.
# Make a single page (1 a4) report of your findings. Use your visualisation skills to communicate your most important findings.

# %%
from mads_datasets import DatasetFactoryProvider, DatasetType

from mltrainer.preprocessors import BasePreprocessor
from mltrainer import imagemodels, Trainer, TrainerSettings, ReportTypes, metrics

import torch.optim as optim
from torch import nn
from tomlserializer import TOMLSerializer
import torch

# %% [markdown]
# We will be using `tomlserializer` to easily keep track of our experiments, and to easily save the different things we did during our experiments.
# It can export things like settings and models to a simple `toml` file, which can be easily shared, checked and modified.
#
# First, we need the data.

# %%
fashionfactory = DatasetFactoryProvider.create_factory(DatasetType.FASHION)
preprocessor = BasePreprocessor()
streamers = fashionfactory.create_datastreamer(batchsize=64, preprocessor=preprocessor)
train = streamers["train"]
valid = streamers["valid"]
trainstreamer = train.stream()
validstreamer = valid.stream()
# Out:
# 2026-01-16 13:02:26.909 | INFO     | mads_datasets.base:download_data:121 - Folder already exists at /home/max/.cache/mads_datasets/fashionmnist
# 2026-01-16 13:02:26.910 | INFO     | mads_datasets.base:download_data:124 - File already exists at /home/max/.cache/mads_datasets/fashionmnist/fashionmnist.pt

# %%
next(trainstreamer)[0][0][0].shape
# Out:
# torch.Size([28, 28])

# %% [markdown]
# We need a way to determine how well our model is performing. We will use accuracy as a metric.

# %%
accuracy = metrics.Accuracy()

# %% [markdown]
# We will use a very basic model: a model with three linear layers.

# %%
class NeuralNetwork(nn.Module):
    def __init__(self,
        num_classes: int,
        units1: int,
        units2: int,
        units3: int,
        # units4: int,
        # units5: int,
        dropout: float
    ) -> None:
        super().__init__()
        # self.num_classes = num_classes
        # self.units1 = units1
        # self.units2 = units2
        # self.units3 = units3
        # self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Conv2d(1, 3, kernel_size=5, stride=2),
            nn.BatchNorm2d(3),
            nn.ReLU(),
            nn.Conv2d(3, 5, kernel_size=3),
            nn.BatchNorm2d(5),
            nn.ReLU(),
            nn.Flatten(),
            nn.Linear(500, units1),
            nn.ReLU(),
            nn.Linear(units1, units2),
            nn.ReLU(),
            nn.Linear(units2, units3),
            nn.BatchNorm1d(units3),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(units3, num_classes),
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        # x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

# %%
import torch

loss_fn = torch.nn.CrossEntropyLoss()

settings = TrainerSettings(
    epochs=16,
    metrics=[accuracy],
    logdir="modellogs_normalisation",
    train_steps=len(train),
    valid_steps=len(valid),
    reporttypes=[ReportTypes.TENSORBOARD, ReportTypes.TOML],
)

model = NeuralNetwork(
    num_classes=10,
    units1=256,
    units2=128,
    units3=64,
    dropout=0.0
)

trainer = Trainer(
    model=model,
    settings=settings,
    loss_fn=loss_fn,
    optimizer=optim.Adam,
    traindataloader=trainstreamer,
    validdataloader=validstreamer,
    scheduler=optim.lr_scheduler.ReduceLROnPlateau
)
trainer.loop()
# Out:
# 2026-01-16 14:35:49.092 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs_normalisation/20260116-143549
# 2026-01-16 14:35:49.093 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 937/937 [00:03<00:00, 248.93it/s]
# 2026-01-16 14:35:53.096 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 0.4803 test 0.4383 metric ['0.8309']
# 100%|██████████| 937/937 [00:03<00:00, 240.39it/s]
# 2026-01-16 14:35:57.242 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.3396 test 0.3799 metric ['0.8582']
# 100%|██████████| 937/937 [00:03<00:00, 242.59it/s]
# 2026-01-16 14:36:01.371 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.3019 test 0.3450 metric ['0.8708']
# 100%|██████████| 937/937 [00:03<00:00, 250.23it/s]
# 2026-01-16 14:36:05.356 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.2687 test 0.3489 metric ['0.8768']
# 2026-01-16 14:36:05.357 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.3450, current loss 0.3489.Counter 1/10.
# 100%|██████████| 937/937 [00:03<00:00, 238.60it/s]
# 2026-01-16 14:36:09.511 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.2471 test 0.3508 metric ['0.8792']
# 2026-01-16 14:36:09.512 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.3450, current loss 0.3508.Counter 2/10.
# 100%|██████████| 937/937 [00:03<00:00, 276.25it/s]
# 2026-01-16 14:36:13.186 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.2245 test 0.3387 metric ['0.8799']
# 100%|██████████| 937/937 [00:03<00:00, 274.01it/s]
# 2026-01-16 14:36:16.837 | INFO     | mltrainer.trainer:report:209 - Epoch 6 train 0.2011 test 0.3602 metric ['0.8771']
# 2026-01-16 14:36:16.838 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.3387, current loss 0.3602.Counter 1/10.
# 100%|██████████| 937/937 [00:03<00:00, 266.18it/s]
# 2026-01-16 14:36:20.589 | INFO     | mltrainer.trainer:report:209 - Epoch 7 train 0.1791 test 0.3482 metric ['0.8843']
# 2026-01-16 14:36:20.589 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.3387, current loss 0.3482.Counter 2/10.
# 100%|██████████| 937/937 [00:03<00:00, 280.89it/s]
# 2026-01-16 14:36:24.243 | INFO     | mltrainer.trainer:report:209 - Epoch 8 train 0.1665 test 0.3669 metric ['0.8813']
# 2026-01-16 14:36:24.244 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.3387, current loss 0.3669.Counter 3/10.
# 100%|██████████| 937/937 [00:04<00:00, 216.99it/s]
# 2026-01-16 14:36:28.859 | INFO     | mltrainer.trainer:report:209 - Epoch 9 train 0.1488 test 0.3837 metric ['0.8864']
# 2026-01-16 14:36:28.860 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.3387, current loss 0.3837.Counter 4/10.
# 100%|██████████| 937/937 [00:03<00:00, 248.12it/s]
# 2026-01-16 14:36:32.882 | INFO     | mltrainer.trainer:report:209 - Epoch 10 train 0.1338 test 0.4131 metric ['0.8800']
# 2026-01-16 14:36:32.883 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.3387, current loss 0.4131.Counter 5/10.
# 100%|██████████| 937/937 [00:04<00:00, 231.61it/s]
# 2026-01-16 14:36:37.180 | INFO     | mltrainer.trainer:report:209 - Epoch 11 train 0.1240 test 0.4295 metric ['0.8780']
# 2026-01-16 14:36:37.181 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.3387, current loss 0.4295.Counter 6/10.
# 100%|██████████| 937/937 [00:03<00:00, 241.22it/s]
# 2026-01-16 14:36:41.332 | INFO     | mltrainer.trainer:report:209 - Epoch 12 train 0.1135 test 0.4281 metric ['0.8815']
# 2026-01-16 14:36:41.333 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.3387, current loss 0.4281.Counter 7/10.
# 100%|██████████| 937/937 [00:03<00:00, 234.77it/s]
# 2026-01-16 14:36:45.617 | INFO     | mltrainer.trainer:report:209 - Epoch 13 train 0.1047 test 0.5018 metric ['0.8788']
# 2026-01-16 14:36:45.617 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.3387, current loss 0.5018.Counter 8/10.
# 100%|██████████| 937/937 [00:04<00:00, 217.32it/s]
# 2026-01-16 14:36:50.212 | INFO     | mltrainer.trainer:report:209 - Epoch 14 train 0.0928 test 0.4695 metric ['0.8813']
# 2026-01-16 14:36:50.213 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.3387, current loss 0.4695.Counter 9/10.
# 100%|██████████| 937/937 [00:05<00:00, 183.65it/s]
# 2026-01-16 14:36:55.623 | INFO     | mltrainer.trainer:report:209 - Epoch 15 train 0.0853 test 0.4768 metric ['0.8794']
# 2026-01-16 14:36:55.624 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.3387, current loss 0.4768.Counter 10/10.
# 2026-01-16 14:36:55.624 | INFO     | mltrainer.trainer:loop:103 - Interrupting loop due to early stopping patience.
# 2026-01-16 14:36:55.625 | INFO     | mltrainer.trainer:loop:108 - early_stopping_save was false, using latest model.Set to true to retrieve best model.
#  94%|█████████▍| 15/16 [01:06<00:04,  4.44s/it]
